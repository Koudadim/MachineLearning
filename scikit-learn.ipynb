# %% [markdown]
# # La libraire scikit learn

# %% [markdown]
# ### La meilleure librairie de machine learning au monde de nos jours ...

# %% [markdown]
# Nous l'utiliserons pour faire de l'apprentissage supervisé

# %% [raw]
# Exemple d'application:
# 1. Prédire le cours de la bourse ou la survenance de tout autre phénomène à partir de données
# 2. Détecter un objet
# 3. Calculer la change de survie dans une catastrophe

# %% [markdown]
# #### Le machine learnng est l'art de donner à la machine la capacité d'apprendre sans la programmer de façon explicite
# #### Il consiste à développer un modèle mathématiques à partir de données expérimentales

# %% [raw]
# Il existe trois techniques :
#     1. L'apprentissage supervisé
#     2. L'apprentissage non-supervisé
#     3. L'apprentissage par renforcement

# %% [markdown]
# Dans l'apprentissage supervisé, la machine reçoit des données caractérisées par des variables x (features) et annotées par une variable y (label / target variable - variable objectif). La machine apprend à prédire y avec les données fournies par x

# %% [raw]
# Procédure :
#     1. Fournir à la machine un dataset volumineux :
#         x, y : tableau numpay à deux dimensions
#     2. Spécifier quel type de modèle la machine doit apprendre (linéaire, polynômial, arbre de décision,
#     réseau de neurones) en précisant les hyperparamètres (nombre de branches, de neurones, ...) du modèle
#         model = LinearRegression(...)
#     3. Grâce à un algorithme d'optimisation, la machine détermine les paramètres optimaux qui offrent les meilleures
#     performances sur le dataset : c'est la phase d'entraînement
#         model.fit(x, y) : entraînement du modèle
#         model.score(x, y) : évaluation du modèle, la machine fait des prédiction et les compare au données expérimentale
#     4. Le modèle de machine learning ainsi entrainé est à être utilisé pour des prédictions
#         model.predict(x) : prédiction si le modèle est adapté

# %% [raw]
# Problèmes solvables grâce à l'apprentissage supervisé machine learning:
#     Régression si y est quantitative continue
#     Classification si y est qualitative discret

# %% [raw]
# Quelques modèles de codes :
#     1. Regression linéaire :
#         model = LinearRegression(...)
#         model.fit(x, y)
#         model.score(x, y)
#         model.predict()
#
#     2. Regression logistique :
#         model = LogisticRegression(...)
#         model.fit(x, y)
#         model.score(x, y)
#         model.predict()
#
#     3. Support Vector Machine SVM :
#         model = SVC(...)
#         model.fit(x, y)
#         model.score(x, y)
#         model.predict()
#
#     4. Random Forest :
#         model = RandomForestClassifier(...)
#         model.fit(x, y)
#         model.score(x, y)
#         model.predict()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Régression avec SKlearn

# %%
np.random.seed(0)
m = 100
x = np.linspace(0, 10, m).reshape(m, 1) # Un échantillon de taille 100
y = x + np.random.randn(m, 1)

# %%
plt.scatter(x, y)
plt.show()

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x, y)
model.score(x, y) # Coefficient de détermination
# Out:
# 0.8881140743377214

# %%
predictions = model.predict(x) # Tableau numpy

# %%
plt.scatter(x, y)
plt.plot(x, predictions, c = 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
# Le cas où y = x**2 + np.random.randn(m, 1)
y = x**2 + np.random.randn(m, 1)

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# La régression linéaire n'est pas adaptée. Le modèle à choisir est le Support Vector machine

# %%
from sklearn.svm import SVR

# %%
model = SVR(C = 100)
model.fit(x, y)
model.score(x, y)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9989035418525655

# %%
predictions = model.predict(x) # Tableau numpy

# %%
plt.scatter(x, y)
plt.plot(x, predictions, c = 'r', lw = 2)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
Au lieu d'utiliser SVR, on pouvait également faire du feature engineering, c'est-à-dire faire de la regression polynômiale

# %% [markdown]
# ### 2. Classification KNN avec SKlearn

# %%
import seaborn as sns

# %%
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df = titanic[['survived', 'pclass', 'sex', 'age']]
df.dropna(axis = 0, inplace = True)
df['sex'].replace(['male', 'female'], [0, 1], inplace = True)
df.head()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_6364\3738664852.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(axis = 0, inplace = True)
# C:\Users\asus\AppData\Local\Temp\ipykernel_6364\3738664852.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sex'].replace(['male', 'female'], [0, 1], inplace = True)
#    survived  pclass  sex   age
# 0         0       3    0  22.0
# 1         1       1    1  38.0
# 2         1       3    1  26.0
# 3         1       1    1  35.0
# 4         0       3    0  35.0

# %% [markdown]
# Le travail consiste à déterminer un modèle pour prédire si un paasager du titanic survivrait où non

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier()

# %%
# Division du tableau

y = df['survived']
x = df.drop('survived', axis = 1)

# %%
model.fit(x, y) # entrainement du modèle
model.score(x, y) # évaluation du modèle
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 0.8417366946778712

# %%
predictions = model.predict(x)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %%
# Fonctions de prédiction de la survie

def survie(model, pclass = 1, sex = 0, age = 25) :
    x = np.array([pclass, sex, age]).reshape(1, 3)
    print(model.predict(x))
    print(model.predict_proba(x)) # La proba d'appartenir à une classe

# %%
survie(model) # Pas survécu
# Out:
# [0]
# [[0.6 0.4]]
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
survie(model, 2, 1, 30) # survécue !
# Out:
# [1]
# [[0. 1.]]
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Résultat avec l'hyperparamètre n_neighbors

# %%
for n in range(1, 11) :
    model = KNeighborsClassifier(n_neighbors = n)
    model.fit(x, y) 
    print(f'Niveau de confiance pour {n} voisins', model.score(x, y))
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
# Autre approche

score = []
best_k = 1
best_score = 0

for k in range(1, 30) :
    model = KNeighborsClassifier(n_neighbors = k)
    model.fit(x, y)
    sc = model.score(x, y)
    score.append(sc)
    
    if best_score < sc :
        best_k = k
        best_score = sc
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
print('best number of neighbors :', best_k)
print('best score:', best_score)
# Out:
# best number of neighbors : 1
# best score: 0.8739495798319328

# %% [markdown]
# ## Technique pour entrainer un modèle, l'optimiser et l'évaluer: Bonne méthodologie

# %% [markdown]
# ### trainset / testset

# %% [markdown]
# En machine learning il ne faut jamais évaluer un modèle sur les mêmes données qui ont servies à son entrainement

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()
x = iris.data
y = iris.target

# %%
print(x.shape)
# Out:
# (150, 4)

# %%
plt.scatter(x[:, 0], x[:, 1], c = y, alpha = 0.8)
plt.show()

# %% [raw]
# Division des données en trainset et testset

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)
print('trainset for x', x_train.shape)
print('test set for x', x_test.shape)
# Out:
# trainset for x (120, 4)
# test set for x (30, 4)

# %%
plt.figure(figsize = (12, 6))
plt.subplot(121)
plt.scatter(x_train[:, 0], x_train[:, 1], c = y_train, alpha = 0.8)
plt.title('TrainSet')

plt.subplot(1, 2, 2)
plt.scatter(x_test[:, 0], x_test[:, 1], c = y_test, alpha = 0.8)
plt.title('TestSet')

plt.show()

# %%
# Contrôler la sélection aléatoire à l'aide du paramètre random_state
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 5)

plt.figure(figsize = (12, 6))
plt.subplot(121)
plt.scatter(x_train[:, 0], x_train[:, 1], c = y_train, alpha = 0.8)
plt.title('TrainSet')

plt.subplot(1, 2, 2)
plt.scatter(x_test[:, 0], x_test[:, 1], c = y_test, alpha = 0.8)
plt.title('TestSet')

plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model = KNeighborsClassifier(n_neighbors = 1)
model.fit(x_train, y_train)
print('train score :', model.score(x_train, y_train))
print('test score :', model.score(x_test, y_test))
# Out:
# train score : 1.0
# test score : 0.9
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %% [markdown]
# ### Validation set / Amélioration du modèle / Cross-validation

# %% [raw]
# On peut améliorer le modèle par des réglages sur les hyperparamètres. Il faut toutefois s'abstenir de faire ces réglages sur le testset car ce dernier servira à évaluer le modèle. D'où la nécessité de subdiviser le dataset en trois :
#     Le trainset,
#     le validationset,
#     Le testset.

# %% [raw]
# Il faut également noter que la façon de découper le dataset impact la qualité du modèle. La score du modèle dépend non seulement des hyperparaètres mais aussi du découpade des données.
# Pour résoudre ce problème, on utilise la cross-validation

# %% [markdown]
# La cross-validation consiste à entrainer puis évaluer un modèle sur plusieurs découpes du dataset

# %%
from sklearn.model_selection import cross_val_score

# %%
#cv : nombre de split du trainset, 
# scoring : métrique
cross_val_score(KNeighborsClassifier(), x_train, y_train, cv = 5, scoring = 'accuracy')
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
# On considère la moyenne des score
cross_val_score(KNeighborsClassifier(), x_train, y_train, cv = 5, scoring = 'accuracy').mean()
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
# Considérons l'hyperparamètres n_neighbors
val_score = []
for k in range(1, 50) :
    score = cross_val_score(KNeighborsClassifier(k), x_train, y_train, cv = 5, scoring = 'accuracy').mean()
    val_score.append(score)
    
print('Liste des scores selon le nombre de voisins', val_score)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
plt.plot(val_score)

# %% [markdown]
# On peut utiliser la fonction 'validation_curve' pour trouver cette courbe!

# %%
from sklearn.model_selection import validation_curve

# %%
model = KNeighborsClassifier()
k = np.arange(1, 51) # tableau du nombre de voisins de 1 à 50

train_score, val_score = validation_curve(model, x_train, y_train, 'n_neighbors', k, cv = 5)

plt.plot(k, val_score.mean(axis = 1), label = 'Validation')
plt.plot(k, train_score.mean(axis = 1), label = 'Train')
plt.xlabel('Neighbors')
plt.ylabel('Scores')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6364\3722509455.py in <module>
#       2 k = np.arange(1, 51) # tableau du nombre de voisins de 1 à 50
#       3
# ----> 4 train_score, val_score = validation_curve(model, x_train, y_train, 'n_neighbors', k, cv = 5)
#       5
#       6 plt.plot(k, val_score.mean(axis = 1), label = 'Validation')
#
# TypeError: validation_curve() takes 3 positional arguments but 5 positional arguments (and 1 keyword-only argument) were given

# %% [markdown]
# ### GridSearchCV

# %% [raw]
# Toujours à la quête de haute performance, GridSearchCV a été mis en place pour prendre en compte plusieurs hyperparamètres tels que la distance, le nombre de voisins, ... afin d'optimiser le modèle

# %% [raw]
# grid = GridSearchCV(model, param_grid, cv)
#
# Il construit une grille de modèles avec toutes les combinaisons possibles d'hyperparamètres prséents dans param_grid (metric, n_neighbors, ...)

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'n_neighbors' : np.arange(1, 20),
             'metric' : ['euclidean', 'manhattan']}

# %%
model = KNeighborsClassifier()
grid = GridSearchCV(model, param_grid, cv = 5)
grid.fit(x_train, y_train)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
# Meilleure score
grid.best_score_
# Out:
# 0.9833333333333334

# %%
# meilleurs paramètres
grid.best_params_
# Out:
# {'metric': 'euclidean', 'n_neighbors': 5}

# %%
# Sauvegarde du meilleur modèle
model = grid.best_estimator_

# %%
# Evaluation du meilleur modèle avec les données nouvelles
model.score(x_test, y_test)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# 0.9333333333333333

# %% [markdown]
# Autre mesure de la performance du modèle: la matrice de confusion

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test, model.predict(x_test))
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# array([[ 8,  0,  0],
#        [ 0,  9,  2],
#        [ 0,  0, 11]], dtype=int64)

# %% [markdown]
# ### Déterminer si le modèle optimal peut être amélioré lorsqu'on lui fournit plus de données pour l'entrainement

# %% [markdown]
# Pour ce faire, on trace la courbe d'apprentissage, la learning_curve

# %% [raw]
# La learning curve montre l'évolution de la qualité du modèle en fonction de la quantité de données qui lui sont fournies

# %%
from sklearn.model_selection import learning_curve

# %%
# train_sizes donne l'ensemble des subdivisions en lots croissants des données fournies au modèle
# cv nombre de division pour la cross-validation
lots, train_score, val_score = learning_curve(model, x_train, y_train, train_sizes = np.linspace(0.1, 1.0, 10), cv = 5)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
print(lots)
# Out:
# [ 9 19 28 38 48 57 67 76 86 96]

# %%
plt.plot(lots, train_score.mean(axis = 1), label = 'Train')
plt.plot(lots, val_score.mean(axis = 1), label = 'Validation')
plt.xlabel('TrainSizes')
plt.legend()
plt.show()

# %% [markdown]
# La performance du modèle se stabilise pour des données de tailles 96x4

# %% [markdown]
# ### 1. Créer un train set et un test set; définir un modèle, l'entrainer et l'évaluer
# ### 2. Utiliser GridSearchCV pour déterminer les meilleurs hyper-paramètres (métrics, n_neighors, weights)
# ### 3. Plus de données sont-elles nécessaires à l'amélioration du modèle?

# %% [raw]
# Les différentes techniques de cross-validation en machine learning:
#
# 1. KFold() : Elle consiste à diviser le train set en k parties égales, puis entrainer le modèle sur toutes les combinaisons possibles de (k-1) de ces parties et valider le modèle sur la partie restante. Elle ne convient pas données de classes déséquilibrées.
#
# 2. LeaveOneOut() : On effectue l'entrainement du modèle sur toutes les données du train set sauf une. On valide le modèle sur cette donnée, puis on la joint au train set. On met à l'écart une autre donnée qui servira à valider le modèle entrainé sur le reste du train set. On procède ainsi autant de fois qui y a de données dans le train set.
#
# 3. ShuffleSplit() : Elle consiste à mélange autant de fois qu'on le souhaite, la train set, et à fois chaque fois, conserver un certain pourcentage pour la validation du modèle que l'on entraine sur l'autre pourcentage. Non adaptée pour des données de classes déséquilibrées.
#
# 4. StratifiedKFold() : Elle permet de résoudre les problèmes de split liés au déséquilibre des classes. A l'instar de KFold, elle découpe le train set en k splits comportant chacun une portion de chaque des classes que présente ces données. Chaque split servira à la valider le model entrainé sur les (k-1) autres splits.

# %%
from sklearn.model_selection import KFold, LeaveOneOut, ShuffleSplit, StratifiedKFold, GroupKFold

# %%
cv = KFold(5)
kfold_cv = cross_val_score(KNeighborsClassifier(), x_train, y_train, cv = cv)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
kfold_cv.mean()
# Out:
# 0.975

# %%
cv = LeaveOneOut()
LOO_cv = cross_val_score(KNeighborsClassifier(), x_train, y_train, cv = cv)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
LOO_cv.mean()
# Out:
# 0.9833333333333333

# %%
cv = ShuffleSplit(5, test_size = 0.2)
SS_cv = cross_val_score(KNeighborsClassifier(), x_train, y_train, cv = cv)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
SS_cv.mean()
# Out:
# 0.9916666666666666

# %%
cv = StratifiedKFold(5)
StratKFold_cv = cross_val_score(KNeighborsClassifier(), x_train, y_train, cv = cv)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
StratKFold_cv.mean()
# Out:
# 0.9833333333333334

# %%
cv = GroupKFold(5).get_n_splits(x_train, y_train, groups = x_train[:, 0])
GKFold_cv = cross_val_score(KNeighborsClassifier(), x_train, y_train, cv = cv)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...

# %%
GKFold_cv.mean()
# Out:
# 0.9833333333333334
